# %%
pip install imutils

# %%
# MAIN
import cv2
import imutils
from keras.models import load_model
from PIL import Image, ImageDraw
import os
import numpy as np
camera = cv2.VideoCapture(0)
model = load_model("Twentyfive_class.model")
IMG_SIZE = 128
top, right, bottom, left = 10, 350, 225, 590
_,first_frame = camera.read()

SAVE_PATH = r"C:\Users\Alka\Desktop\lets study\semester 2\IT workshop"
#camera.release()
first_gray = cv2.flip(first_frame, 1)
roi = first_gray[top:bottom, right:left]
img_count = 1
dictonary = {'A':0, 'B':1, 'C':2, 'D':3, 'E':4, 'F':5, 'G':6, 'H':7, 'I':8,'J':9, 'K':10, 'L':11, 'M':12, 'N':13, 'O':14, 'P':15, 
            'Q':16, 'R':17, 'S':18, 'T':19, 'U':20, 'V':21, 'W':22, 'X':23, 'Y':24,'Z':25}
num_class = 26
out = ""
inv_dictonary = dict(map(reversed, dictonary.items()))
string = ""
while True:
    
    _, frame = camera.read()
    
    gray_frame = cv2.flip(frame, 1)
    
    #gray_frame = cv2.cvtColor(gray_frame, cv2.COLOR_BGR2GRAY)
    #gray_frame = cv2.GaussianBlur(gray_frame, (35,35), 0)
    
    roi2 = gray_frame[top:bottom, right:left]
    cv2.rectangle(gray_frame, (left, top), (right, bottom), (0,255,0), 2)
    
    diff = cv2.absdiff(roi, roi2)
    diff = cv2.cvtColor(diff, cv2.COLOR_BGR2GRAY)
    diff = cv2.GaussianBlur(diff, (11,11),0)
    _,diff = cv2.threshold(diff, 10, 255, cv2.THRESH_BINARY)
    
    cv2.imshow("Diff", diff)
    
    
    key = cv2.waitKey(1)
    if key == 27:
        break
    if key == ord('q'):
        break
    if key == ord('r'):
        roi = gray_frame[top:bottom, right:left]
        string = ""
    
    # PREDICTION
    
    #img = cv2.cvtColor(diff, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(diff, (IMG_SIZE, IMG_SIZE))
    
    img_arr = np.array(img)

    t2 = np.expand_dims(img_arr, axis=-1)
    t2 = np.expand_dims(t2, axis=0)

    p = model.predict(t2)
    p2 = np.argmax(p)
    out = inv_dictonary[p2]
    
    #PREDICTION ENDS
    
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(gray_frame,out, (22,34), font, 1, (200,255,255), 2, cv2.LINE_AA)
    cv2.putText(gray_frame,string, (22,64), font, 1, (200,255,255), 2, cv2.LINE_AA)
    #cv2.putText(gray_frame,"r: Reset", (22,400), font, 1, (200,255,255), 2, cv2.LINE_AA)
    #cv2.putText(gray_frame,"s: Append word", (22,430), font, 1, (200,255,255), 2, cv2.LINE_AA)
    cv2.putText(gray_frame,"r: Reset;  s: Append;  q: Quit", (22,470), font, 1, (200,255,255), 2, cv2.LINE_AA)
    
    cv2.imshow("Frame", gray_frame)
    if key == ord('s'):
        string = string+""+out
    
    #cv2.imshow("Frame", gray_frame)
    
    if key == ord('c'):
        img_name = "data{}.png".format(img_count)
        img_count+=1
        cv2.imwrite(os.path.join(SAVE_PATH, img_name), diff)
        
        img_name = "data{}.png".format(img_count)
        img_count+=1
        cv2.imwrite(os.path.join(SAVE_PATH, img_name), gray_frame)
        
        img_name = "data{}.png".format(img_count)
        img_count+=1
        cv2.imwrite(os.path.join(SAVE_PATH, img_name), roi2)
        #cv2.imwrite(img_name, roi2)
        
camera.release()
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
import cv2

# %%
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])
# plt.title("Accuracy")
# plt.xlabel('epoch')
# plt.ylabel('accuracy')
# plt.legend(['train','test'])
# plt.show()

# %%
from keras.models import load_model
m = load_model('Twentyfive_class.model')
test_data = os.listdir('data/test')
x, y = [], []
for ix in test_data:
    images = os.listdir('data/test/' + ix)
    for cx in range(1,201):
        img_path = 'data/test/' + ix + '/' + str(cx) + '.jpg'
        img = cv2.imread(img_path, 0)
        img = img.reshape((200,200,1))
        img = img/255.0
        x.append(img)
        y.append(dict_labels[ix])
X_t = np.array(x)
y_t = np.array(y)
Y_t = np_utils.to_categorical(y_t)
X_t.shape

# %%
y_pred = m.predict(X_t)
from sklearn.metrics import accuracy_score
accuracy_score(Y_t, y_pred.round())
0.7985416666666667
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_pred.round(), Y_t))

# %%
import cv2
# import imutils
from keras.models import load_model
# from PIL import Image, ImageDraw
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
cap=cv2.VideoCapture(0)
model = load_model("Twentyfive_class.model")

img_size = 128
top, right, bottom, left = 10, 350, 225, 590


SAVE_PATH = r"C:\Users\Alka\Desktop\lets study\semester 2\IT workshop"

dictonary = {'A':0, 'B':1, 'C':2, 'D':3, 'E':4, 'F':5, 'G':6, 'H':7, 'I':8,'J':9, 'K':10, 'L':11, 'M':12, 'N':13, 'O':14, 'P':15, 
            'Q':16, 'R':17, 'S':18, 'T':19, 'U':20, 'V':21, 'W':22, 'X':23, 'Y':24,'Z':25}

out = ""
inv_dic = dict(map(reversed, dictonary.items()))
string = ""

count=0
total=26

while True:
    flag, frame=cap.read()
    blur=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    blur=cv2.GaussianBlur(blur,(11,11),0)
    diff = cv2.threshold(blur, 10, 255, cv2.THRESH_BINARY)
    cv2.imshow("diff",diff[1])
    
    key = cv2.waitKey(1)
    if key == 27:
        break
    if key == ord('q'):
        break
    if key == ord('r'):
        roi = blur[top:bottom, right:left]
        string = ""
        
    
    ##PREDICTION
    
    img=cv2.resize(diff[1],(img_size,img_size))
    
    img_arr=np.array(img)
    img_arr=img_arr.reshape(128)
    
    p=model.predict(img_arr)
    out=inv_dic[p]
    
    ## PREDICTION END
    
    
     
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(blur,out, (22,34),cv.FONT_HERSHEY_SIMPLEX , 1, (200,255,255), 2, cv2.LINE_AA)
    cv2.putText(blur,string, (22,64), cv.FONT_HERSHEY_SIMPLEX, 1, (200,255,255), 2, cv2.LINE_AA)
    cv2.putText(blur,"r: Reset;  s: Append;  q: Quit", (22,470), cv.FONT_HERSHEY_SIMPLEX, 1, (200,255,255), 2, cv2.LINE_AA)
    
    cv2.imshow("Frame",blur)
    if key == ord('s'):
        string = string+""+out
    
    if key == ord('c'):
        img_name = "data{}.png".format(img_count)
        img_count+=1
        cv2.imwrite(os.path.join(SAVE_PATH, img_name), diff)
        
        img_name = "data{}.png".format(img_count)
        img_count+=1
        cv2.imwrite(os.path.join(SAVE_PATH, img_name), gray_frame)
        
        img_name = "data{}.png".format(img_count)
        img_count+=1
        cv2.imwrite(os.path.join(SAVE_PATH, img_name), roi2)
        #cv2.imwrite(img_name, roi2)
    
    
        
cap.release()
cv2.destroyAllWindows()
